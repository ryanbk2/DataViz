# %% [markdown]
# # For Peers

# %% [markdown]
# **This is a chart showing the points per game distribution from 2021-2022 season, showing points per gaame based on shooting efficiency for all players active during the season, labeled on a scatter plot.**

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import panel as pn
import numpy as np

# %%
df = pd.read_csv('all_seasons.csv')
df.head()
# Out:
#    Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0           0      Dennis Rodman               CHI  36.0         198.12
# 1           1  Dwayne Schintzius               LAC  28.0         215.90
# 2           2       Earl Cureton               TOR  39.0         205.74
# 3           3        Ed O'Bannon               DAL  24.0         203.20
# 4           4        Ed Pinckney               MIA  34.0         205.74
#
#    player_weight                      college country draft_year draft_round  \
# 0      99.790240  Southeastern Oklahoma State     USA       1986           2
# 1     117.933920                      Florida     USA       1990           1
# 2      95.254320                Detroit Mercy     USA       1979           3
# 3     100.697424                         UCLA     USA       1995           1
# 4     108.862080                    Villanova     USA       1985           1
#
# ...

# %%
df_2022 = df[df['season'] == '2021-22']
df_2022.head()
# Out:
#        Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 11700       11700  Freddie Gillespie               ORL  25.0         205.74
# 11701       11701      Georges Niang               PHI  29.0         200.66
# 11702       11702        George King               DAL  28.0         198.12
# 11703       11703        George Hill               MIL  36.0         193.04
# 11704       11704     Gary Trent Jr.               TOR  23.0         195.58
#
#        player_weight                      college country draft_year  \
# 11700     111.130040                       Baylor     USA  Undrafted
# 11701     104.326160                   Iowa State     USA       2016
# 11702      99.790240                     Colorado     USA       2018
# 11703      85.275296  Indiana-Purdue Indianapolis     USA       2008
# 11704      94.800728                         Duke     USA       2018
#
#       draft_round  ...   pts  reb  ast  net_rating  oreb_pct  dreb_pct  \
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 6))
x = df['ts_pct']
y = df['pts']
sns.scatterplot(x, y)
plt.xlabel("Shooting Efficiency")
plt.ylabel("Points per Game")
plt.show()
# Out:
# C:\Users\TermnL\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
