# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('store_data.csv', encoding_errors='ignore')

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# Profit by State

df_store = df.groupby('State')['Profit'].sum()
df_store
# Out:
# State
# Alabama                  5786.8253
# Arizona                 -3427.9246
# Arkansas                 4008.6871
# California              76381.3871
# Colorado                -6527.8579
# Connecticut              3511.4918
# Delaware                 9977.3748
# District of Columbia     1059.5893
# Florida                 -3399.3017
# Georgia                 16250.0433
# Idaho                     826.7231
# Illinois               -12607.8870
# Indiana                 18382.9363
# Iowa                     1183.8119
# Kansas                    836.4435
# Kentucky                11199.6966
# Louisiana                2196.1023
# Maine                     454.4862
# Maryland                 7031.1788
# Massachusetts            6785.5016
# Michigan                24463.1876
# Minnesota               10823.1874
# Mississippi              3172.9762
# Missouri                 6436.2105
# Montana                  1833.3285
# Nebraska                 2037.0942
# ...

# %%
# Profit for all the cities of Texas

df_texas = df[df['State'] == 'Texas']
df_tx = df_texas.groupby('City')['Profit'].sum()
df_tx
# Out:
# City
# Abilene               -3.7584
# Allen                -39.8775
# Amarillo            -387.9683
# Arlington           -254.3886
# Austin               -20.3938
# Baytown                3.6288
# Beaumont              59.1164
# Bedford               10.6202
# Brownsville          202.0720
# Bryan               -213.7116
# Carrollton          -470.2139
# Cedar Hill            42.8316
# College Station     -117.6224
# Conroe                 6.9795
# Coppell               41.4892
# Corpus Christi       -43.7304
# Dallas             -2846.5257
# Deer Park            -10.3860
# Edinburg              27.8086
# El Paso             -179.9007
# Fort Worth           298.7327
# Frisco               -18.8016
# Garland              -32.3730
# Grand Prairie        -85.2311
# Grapevine              8.7749
# Haltom City           51.9558
# Harlingen             18.1275
# Houston           -10153.5485
# Huntsville          -843.4264
# Irving              -100.5125
# Keller                 2.1000
# ...

# %%
plt.figure(figsize=(25,25))
plt.rcParams.update({'font.size': 22})
df_store.plot.bar(title="Profit by State", xlabel="State", ylabel="Total Profit")
# Out:
# <AxesSubplot:title={'center':'Profit by State'}, xlabel='State', ylabel='Total Profit'>

# %%
plt.figure(figsize=(15,10))
plt.rcParams.update({'font.size': 15})
df_tx.plot.bar(title="Profit by Each City in Texas", xlabel="City", ylabel="Total Profit", color='crimson')
# Out:
# <AxesSubplot:title={'center':'Profit by Each City in Texas'}, xlabel='City', ylabel='Total Profit'>
